# %% [markdown]
# # 1) Corrigindo Inconstitências em Watched -> watched_enriched_cleaned

# %%
import pandas as pd

watched = pd.read_csv("../data/processed/watched_enriched.csv")

watched.head(10)
# Out:
#                               Name  Year  Rating  duration_min  \
# 0                Midnight in Paris  2011     5.0          94.0
# 1         The Pursuit of Happyness  2006     5.0         117.0
# 2                 Mr. & Mrs. Smith  2005     4.0         119.0
# 3             Inglourious Basterds  2009     5.0         153.0
# 4  The Perks of Being a Wallflower  2012     5.0         103.0
# 5                   Fahrenheit 451  2018     1.0         100.0
# 6                   Before Sunrise  1995     3.5         101.0
# 7             The Name of the Rose  1986     5.0         130.0
# 8                 The Untouchables  1987     5.0         119.0
# 9                            Elvis  2022     3.0         159.0
#
#                              genres             director         lead_actor  \
# 0          Fantasy, Comedy, Romance          Woody Allen        Owen Wilson
# 1                             Drama     Gabriele Muccino         Will Smith
# ...

# %%
watched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          650 non-null    object
#  1   Year          650 non-null    int64
#  2   Rating        650 non-null    float64
#  3   duration_min  642 non-null    float64
#  4   genres        642 non-null    object
#  5   director      641 non-null    object
#  6   lead_actor    642 non-null    object
#  7   vote_average  642 non-null    float64
#  8   budget        642 non-null    float64
#  9   revenue       642 non-null    float64
#  10  release_date  642 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 56.0+ KB

# %%
watched.describe()
# Out:
#               Year      Rating  duration_min  vote_average        budget  \
# count   650.000000  650.000000    642.000000    642.000000  6.420000e+02
# mean   2000.661538    3.669231    120.174455      7.255743  5.735039e+07
# std      21.085326    0.641268     29.117934      0.699451  6.670370e+07
# min    1895.000000    0.500000      1.000000      4.610000  0.000000e+00
# 25%    1994.000000    3.500000    103.000000      6.759250  8.925000e+06
# 50%    2006.000000    4.000000    117.000000      7.333000  3.125000e+07
# 75%    2014.000000    4.000000    134.000000      7.769000  8.075000e+07
# max    2025.000000    5.000000    335.000000      8.711000  4.654000e+08
#
#             revenue
# count  6.420000e+02
# mean   2.718776e+08
# std    3.294238e+08
# min    0.000000e+00
# 25%    3.575297e+07
# 50%    1.526977e+08
# 75%    3.932389e+08
# max    2.264162e+09

# %%
watched[watched.isnull().any(axis=1)]
# Out:
#                                     Name  Year  Rating  duration_min  \
# 175                O Auto da Compadecida  1999     5.0           NaN
# 459                           Squid Game  2021     4.5          30.0
# 465                      Smiling Friends  2020     3.5           NaN
# 473    Black Mirror: The National Anthem  2011     4.0           NaN
# 527  Workers Leaving the Lumière Factory  1895     4.0           NaN
# 531                 Demolition of a Wall  1896     3.5           NaN
# 532                       Snowball Fight  1897     3.5           NaN
# 535               The Mechanical Butcher  1896     3.0           NaN
# 536                         Divertimento  2022     4.0           NaN
#
#           genres director    lead_actor  vote_average  budget  revenue  \
# 175          NaN      NaN           NaN           NaN     NaN      NaN
# 459  Documentary      NaN  Nicola Brown          7.66     0.0      0.0
# ...

# %%
watched[watched.eq(0).any(axis=1)]
# Out:
#                                Name  Year  Rating  duration_min  \
# 5                    Fahrenheit 451  2018     1.0         100.0
# 17            Miracle in Cell No. 7  2019     4.0         132.0
# 27                          22 July  2018     3.0         143.0
# 45                             Hush  2016     3.5          82.0
# 61   The Stanford Prison Experiment  2015     4.0         122.0
# ..                              ...   ...     ...           ...
# 609                          Hustle  2022     3.5         117.0
# 610                 The Rat Catcher  2023     3.0          17.0
# 621                  Back in Action  2025     2.0         114.0
# 624  Lunana: A Yak in the Classroom  2019     4.5         109.0
# 631         35 - O Assalto ao Poder  2002     3.5          98.0
#
#                                genres              director  \
# 5    Drama, Science Fiction, Thriller         Ramin Bahrani
# 17                              Drama    Mehmet Ada Öztekin
# ...

# %% [markdown]
# Durante o processo de integração dos dados (TMDB + Letterboxd), alguns dos filmes presentes na minha watchlist foram completados com nulos e outros com valor zero, muito provavelmente pela falta de dados correspondentes no TMDB.
# 1. Valores nulos: como a maioria dos poucos registros com valores nulos são series (e a maioria dos demais são filmes curtíssimos dos irmãosLumière) eu optei por simplesmente apagá-los.
# 2. Valor zerados: como um número razoável de filmes possui valorees faltantes (aqui representados por zero) para as colunas Budget e Revenue, decidi simplesmente apagá-las.

# %%
watched = watched.drop(columns=['budget', 'revenue', 'release_date'])
watched.head()
# Out:
#                               Name  Year  Rating  duration_min  \
# 0                Midnight in Paris  2011     5.0          94.0
# 1         The Pursuit of Happyness  2006     5.0         117.0
# 2                 Mr. & Mrs. Smith  2005     4.0         119.0
# 3             Inglourious Basterds  2009     5.0         153.0
# 4  The Perks of Being a Wallflower  2012     5.0         103.0
#
#                             genres           director    lead_actor  \
# 0         Fantasy, Comedy, Romance        Woody Allen   Owen Wilson
# 1                            Drama   Gabriele Muccino    Will Smith
# 2  Action, Comedy, Drama, Thriller         Doug Liman     Brad Pitt
# 3             Drama, Thriller, War  Quentin Tarantino     Brad Pitt
# 4                            Drama    Stephen Chbosky  Logan Lerman
#
#    vote_average
# 0         7.523
# 1         7.891
# 2         6.689
# 3         8.215
# 4         7.795

# %%
watched = watched.dropna().reset_index(drop=True)
watched[watched.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Rating, duration_min, genres, director, lead_actor, vote_average]
# Index: []

# %%
watched.describe()
# Out:
#               Year      Rating  duration_min  vote_average
# count   641.000000  641.000000    641.000000    641.000000
# mean   2001.205928    3.666147    120.315133      7.255112
# std      19.492740    0.641721     28.921509      0.699815
# min    1895.000000    0.500000      1.000000      4.610000
# 25%    1995.000000    3.500000    103.000000      6.758000
# 50%    2006.000000    4.000000    117.000000      7.333000
# 75%    2014.000000    4.000000    134.000000      7.773000
# max    2025.000000    5.000000    335.000000      8.711000

# %%
watched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          641 non-null    object
#  1   Year          641 non-null    int64
#  2   Rating        641 non-null    float64
#  3   duration_min  641 non-null    float64
#  4   genres        641 non-null    object
#  5   director      641 non-null    object
#  6   lead_actor    641 non-null    object
#  7   vote_average  641 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 40.2+ KB

# %%
watched.to_csv('../data/cleaned/watched_enriched_cleaned.csv', index=False)

# %% [markdown]
# # 2) Corrigindo Inconstitências em Watchlist -> watchlist_enriched_cleaned

# %%
watchlist = pd.read_csv("../data/processed/watchlist_enriched.csv")
watchlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          359 non-null    object
#  1   Year          359 non-null    int64
#  2   duration_min  356 non-null    float64
#  3   genres        355 non-null    object
#  4   director      356 non-null    object
#  5   lead_actor    356 non-null    object
#  6   vote_average  356 non-null    float64
#  7   budget        356 non-null    float64
#  8   revenue       356 non-null    float64
#  9   release_date  356 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 28.2+ KB

# %%
watchlist = watchlist.drop(columns=['budget', 'revenue', 'release_date'])
watchlist.head()
# Out:
#                                     Name  Year  duration_min  \
# 0                             La La Land  2016         129.0
# 1                                   Dune  2021         155.0
# 2  Eternal Sunshine of the Spotless Mind  2004         108.0
# 3                             Uncut Gems  2019         136.0
# 4                             Hereditary  2018         128.0
#
#                             genres          director         lead_actor  \
# 0    Comedy, Drama, Romance, Music   Damien Chazelle       Ryan Gosling
# 1       Science Fiction, Adventure  Denis Villeneuve  Timothée Chalamet
# 2  Science Fiction, Drama, Romance     Michel Gondry         Jim Carrey
# 3           Drama, Thriller, Crime      Benny Safdie       Adam Sandler
# 4        Horror, Mystery, Thriller         Ari Aster      Toni Collette
#
#    vote_average
# 0         7.900
# 1         7.782
# 2         8.092
# 3         7.200
# 4         7.291

# %%
watchlist[watchlist.isnull().any(axis=1)]
# Out:
#                                       Name  Year  duration_min genres  \
# 227  Tulsa Burning: The 1921 Race Massacre  2021           NaN    NaN
# 284                              Nostalgia  1983           1.0    NaN
# 293    The Roosevelts: An Intimate History  2014           NaN    NaN
# 341      Images of the Estado Novo 1937-45  2016           NaN    NaN
#
#       director lead_actor  vote_average
# 227        NaN        NaN           NaN
# 284  Evan Bean  Evan Bean           0.0
# 293        NaN        NaN           NaN
# 341        NaN        NaN           NaN

# %%
watchlist = watchlist.dropna().reset_index(drop=True)
watchlist[watchlist.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Year, duration_min, genres, director, lead_actor, vote_average]
# Index: []

# %%
watchlist.describe()
# Out:
#               Year  duration_min  vote_average
# count   355.000000    355.000000    355.000000
# mean   1990.887324    117.535211      7.110324
# std      25.208593     43.332322      1.130428
# min    1915.000000      0.000000      0.000000
# 25%    1974.000000     98.000000      6.800000
# 50%    1995.000000    114.000000      7.278000
# 75%    2012.000000    132.000000      7.640500
# max    2024.000000    566.000000     10.000000

# %%
watchlist[watchlist.eq(0).any(axis=1)]
# Out:
#                                                   Name  Year  duration_min  \
# 20                                Over the Garden Wall  2014          50.0
# 142                                      Night and Fog  1956           0.0
# 228                                             Bolero  1981          68.0
# 269                                           Aquarius  2016           9.0
# 313  Hit Them Hard! The Brazilian Fighter Squadron ...  1999           0.0
# 338                          1930 - Tempo de Revolução  1990           0.0
# 340                     Rondon - O sentimento da terra  1992           0.0
# 350                                        Grizzly Man  2005          54.0
#
#                              genres          director  \
# 20                  Romance, Comedy       David Smith
# 142                          Horror     Weibang Ma-Xu
# 228                 Science Fiction  Gregory Hatanaka
# 269  Fantasy, Music, Drama, Romance   Timofey Zhalnin
# ...

# %%
# Apagando série
watchlist = watchlist.drop(index=20).reset_index(drop=True)
watchlist[watchlist.eq(0).any(axis=1)]
# Out:
#                                                   Name  Year  duration_min  \
# 141                                      Night and Fog  1956           0.0
# 227                                             Bolero  1981          68.0
# 268                                           Aquarius  2016           9.0
# 312  Hit Them Hard! The Brazilian Fighter Squadron ...  1999           0.0
# 337                          1930 - Tempo de Revolução  1990           0.0
# 339                     Rondon - O sentimento da terra  1992           0.0
# 349                                        Grizzly Man  2005          54.0
#
#                              genres          director  \
# 141                          Horror     Weibang Ma-Xu
# 227                 Science Fiction  Gregory Hatanaka
# 268  Fantasy, Music, Drama, Romance   Timofey Zhalnin
# 312                     Documentary    Erik de Castro
# 337                     Documentary   Eduardo Escorel
# ...

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'] == 'Night and Fog', [
    'duration_min', 'genres', 'director', 'lead_actor', 'vote_average'
]] = [32.0, 'Documentary, History', 'Alain Resnais', 'Michel Bouquet', 8.2]
watchlist[watchlist['Name'] == 'Night and Fog']
# Out:
#               Name  Year  duration_min                genres       director  \
# 141  Night and Fog  1956          32.0  Documentary, History  Alain Resnais
#
#          lead_actor  vote_average
# 141  Michel Bouquet           8.2

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'] == 'Bolero', [
    'duration_min', 'genres', 'director', 'lead_actor', 'vote_average'
]] = [184.0, 'Drama, Music', 'Claude Lelouch', 'Robert Hossein', 7.0]
watchlist[watchlist['Name'] == 'Bolero']
# Out:
#        Name  Year  duration_min        genres        director      lead_actor  \
# 227  Bolero  1981         184.0  Drama, Music  Claude Lelouch  Robert Hossein
#
#      vote_average
# 227           7.0

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'] == 'Aquarius', [
    'duration_min', 'genres', 'director', 'lead_actor', 'vote_average'
]] = [147.0, 'Drama', 'Kleber Mendonça Filho', 'Sônia Braga', 7.5]
watchlist[watchlist['Name'] == 'Aquarius']
# Out:
#          Name  Year  duration_min genres               director   lead_actor  \
# 268  Aquarius  2016         147.0  Drama  Kleber Mendonça Filho  Sônia Braga
#
#      vote_average
# 268           7.5

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'].str.contains('Hit Them Hard', case=False), [
    'duration_min', 'genres', 'director', 'lead_actor', 'vote_average'
]] = [112.0, 'Documentary, War, History', 'Erik de Castro', 'Newton Neiva de Figueiredo', 7.0]
watchlist[watchlist['Name'].str.contains('Hit Them Hard', case=False)]
# Out:
#                                                   Name  Year  duration_min  \
# 312  Hit Them Hard! The Brazilian Fighter Squadron ...  1999         112.0
#
#                         genres        director                  lead_actor  \
# 312  Documentary, War, History  Erik de Castro  Newton Neiva de Figueiredo
#
#      vote_average
# 312           7.0

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'].str.contains('1930', case=False), 'duration_min'] = 48.0
watchlist[watchlist['Name'].str.contains('1930', case=False)]
# Out:
#                           Name  Year  duration_min       genres  \
# 337  1930 - Tempo de Revolução  1990          48.0  Documentary
#
#             director   lead_actor  vote_average
# 337  Eduardo Escorel  Edwin Luisi           5.5

# %%
# Corrigindo e completando valores:
watchlist.loc[watchlist['Name'] == 'Grizzly Man', [
    'duration_min', 'genres', 'director', 'lead_actor', 'vote_average'
]] = [103.0, 'Documentary', 'Werner Herzog', 'Timothy Treadwell', 7.5]
watchlist[watchlist['Name'] == 'Grizzly Man']
# Out:
#             Name  Year  duration_min       genres       director  \
# 349  Grizzly Man  2005         103.0  Documentary  Werner Herzog
#
#             lead_actor  vote_average
# 349  Timothy Treadwell           7.5

# %%
# Corrigindo e completando valores (não encontrei informações acerca do tempo de duração):
watchlist = watchlist[~watchlist['Name'].str.contains('Rondon', case=False)].reset_index(drop=True)

# Checando
watchlist[watchlist.eq(0).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Year, duration_min, genres, director, lead_actor, vote_average]
# Index: []

# %%
watchlist.to_csv('../data/cleaned/watchlist_enriched_cleaned.csv', index=False)
